# %%
import numpy as np
import pandas as pd

input_path = "C:/Users/antho/OneDrive/Documents/Repositories/delapan-fantasy/data/models/training_inputs/by_slate/training_inputs_20250205.parquet"

inputs = pd.read_parquet(input_path)

display(inputs.head())
# Out:
#    pts_avg_3  pts_std_3  pts_min_3  pts_max_3  pts_avg_10  pts_std_10  \
# 0  10.666667   4.041452          7         15   10.666667    4.041452
# 1  11.666667   4.163332          7         15   11.250000    3.500000
# 2  13.333333   1.527525         12         15   11.400000    3.049590
# 3  10.333333   3.785939          6         13   10.500000    3.507136
# 4  10.333333   3.785939          6         13   10.857143    3.338092
#
#    pts_min_10  pts_max_10   pts_ewma  reb_avg_3  ...  usage_std_3  \
# 0           7          15  11.000000   5.333333  ...     2.551085
# 1           7          15  11.666667   4.666667  ...     2.366101
# 2           7          15  11.777778   4.333333  ...     2.772165
# 3           6          15   9.851852   5.000000  ...     3.926402
# 4           6          15  10.901235   5.000000  ...     1.864439
#
#    usage_min_3  usage_max_3  usage_avg_10  usage_std_10  usage_min_10  \
# 0        15.67        20.76     18.113333      2.551085         15.67
# ...

# %%
import sys
from pathlib import Path
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

repo_root = Path.cwd().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.utils.fantasy_points import calculate_dk_fantasy_points

# %%
calculate_dk_fantasy_points(inputs)
# Out:
# 0.0

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd()))

repo_root = Path.cwd().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))


from src.data.collectors.tank01_client import Tank01Client
import json
import os
from dotenv import load_dotenv

load_dotenv()


client = Tank01Client(api_key=os.getenv('TANK01_API_KEY'), 

                      )

print("Fetching teams from Tank01 API...")
print("=" * 80)

teams = client.get_teams(
    schedules='true', 
    rosters = 'true',
    statsToGet = 'true', 
    topPerformers = 'true',
    teamStats = 'true'
    )

print(teams)

print(f"\nRemaining API requests: {client.get_remaining_requests()}")
# Out:
# Fetching teams from Tank01 API...
# ...

# %%
import pandas as pd

teams = pd.DataFrame(teams['body'])

schedule = teams['teamSchedule']

# %%
schedule = pd.DataFrame(schedule)

print(schedule.head())
# Out:
#                                         teamSchedule
# 0  {'20251229_ORL@TOR': {'gameID': '20251229_ORL@...
# 1  {'20251107_UTA@MIN': {'gameID': '20251107_UTA@...
# 2  {'20260206_MIA@BOS': {'gameID': '20260206_MIA@...
# 3  {'20260206_MIA@BOS': {'gameID': '20260206_MIA@...
# 4  {'20251108_PHO@LAC': {'gameID': '20251108_PHO@...
